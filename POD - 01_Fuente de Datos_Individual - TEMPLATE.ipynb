# %% [markdown]
# ```
# # Esto tiene formato de código
# ```
#
# *   **Año:** 2024
# *   **Alumno/a:** Juan Cruz Di Meglio
# *   **Legajo:** [1202823]

# %% [markdown]
# # Archivos de texto plano
#
# [gutenberg.org](https://www.gutenberg.org/) (llamado así por el inventor de la imprenta moderna) es el sitio web del Proyecto Gutenberg que se dedica a la distribución y creación de eBooks. En este sitio se encuentra el [Don Quijote](https://www.gutenberg.org/ebooks/14859). El Don Quijote se puede leer en diferentes formatos, ¿no? Para la tarea, se va a usar el Don Quijote de texto plano. La siguiente celda descarga el .txt y lo guarda en el sistema para luego su futura lectura:

# %%
# !wget https://www.gutenberg.org/cache/epub/2000/pg2000.txt
# Out:
# --2024-11-22 17:00:01--  https://www.gutenberg.org/cache/epub/2000/pg2000.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2225845 (2.1M) [text/plain]
# Saving to: ‘pg2000.txt’
#
# pg2000.txt          100%[===================>]   2.12M  5.69MB/s    in 0.4s
#
# 2024-11-22 17:00:02 (5.69 MB/s) - ‘pg2000.txt’ saved [2225845/2225845]

# %% [markdown]
# ## Consignas

# %% [markdown]
# ***NOTA: Para estas consignas, no se puede usar modulos externos a Python***

# %% [markdown]
# Del archivo descargado, calcular la cantidad de lineas:

# %%
archivo=open("pg2000.txt", "r")
lineas=archivo.readlines()
cont=0
for i in lineas:
  cont+=1
print(cont)
# Out:
# 38055

# %% [markdown]
# Del archivo descargado, calcular la cantidad de veces que se dice:
# *   'Quijote'
# *   'mancha'
# *   'españa'
#
# Considerar que, por ejemplo, 'QuiJoTe' es lo mismo que 'quijote' (no *case sensitive*).

# %%
text = "".join(lineas).lower()
contq = text.count('quijote')
contm = text.count('mancha')
conte = text.count('españa')
print("Quijote count:", contq)
print("Mancha count:", contm)
print("España count:", conte)
# Out:
# Quijote count: 2249
# Mancha count: 196
# España count: 78

# %% [markdown]
# ¿Quien es el autor y titulo del libro? Responderlo usando las herramientas utilizadas en la celda anterior (Tip: abrir el archivo de texto y ver como son las primeras lineas).

# %%
#Escribir el codigo para responder la pregunta en esta celda
titulo= lineas[10]
autor=lineas[12]
print(autor,titulo)
# Out:
# Author: Miguel de Cervantes Saavedra
#  Title: Don Quijote

# %% [markdown]
# # Archivos .csv
#
# *Robert* De Niro actuó en mas de 100 peliculas y Rotten Tomatoes es un sitio web en el que se pueden leer criticas y ratings a peliculas hechos por críticos y usuarios. La siguiente linea descarga un archivo .csv en el que tenemos peliculas de De Niro junto a su rating en Rotten Tomatoes:

# %%
# !wget https://people.sc.fsu.edu/~jburkardt/data/csv/deniro.csv
# Out:
# --2024-11-22 17:00:20--  https://people.sc.fsu.edu/~jburkardt/data/csv/deniro.csv
# Resolving people.sc.fsu.edu (people.sc.fsu.edu)... 144.174.0.22
# Connecting to people.sc.fsu.edu (people.sc.fsu.edu)|144.174.0.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2391 (2.3K) [text/csv]
# Saving to: ‘deniro.csv’
#
# deniro.csv          100%[===================>]   2.33K  --.-KB/s    in 0s
#
# 2024-11-22 17:00:20 (675 MB/s) - ‘deniro.csv’ saved [2391/2391]

# %% [markdown]
# ## Consignas

# %% [markdown]
# ***NOTA: Apartir de aca, se pueden usar modulos externos de Python***

# %% [markdown]
# Sabemos que el archivo tiene en su primera linea los 'headers'. ¿Cuales son? Imprimirlos.

# %%
#Escribir el codigo para responder la pregunta en esta celda

import csv
f=open("deniro.csv","r")
linea=csv.reader(f)
headers=next(linea)
print(headers)
# Out:
# ['Year', ' "Score"', ' "Title"']

# %% [markdown]
# Convertir la información del archivo .csv a un diccionario.

# %%
#Escribir el codigo para responder la pregunta en esta celda

import csv

f = open("deniro.csv", "r")
linea = csv.reader(f)
diccionario = {}

for columnas in linea:
  if len(columnas) >= 2:
    diccionario[columnas[2]] =[columnas[1],columnas[0]]

print(diccionario)
# Out:
# {' "Title"': [' "Score"', 'Year'], ' "Greetings"': ['  86', '1968'], ' "Bloody Mama"': ['  17', '1970'], ' "Hi': ['  73', '1970'], ' "Born to Win"': ['  40', '1971'], ' "Mean Streets"': ['  98', '1973'], ' "Bang the Drum Slowly"': ['  88', '1973'], ' "The Godfather': ['  97', '1974'], ' "The Last Tycoon"': ['  41', '1976'], ' "Taxi Driver"': ['  99', '1976'], ' "1900"': ['  47', '1977'], ' "New York': ['  67', '1977'], ' "The Deer Hunter"': ['  93', '1978'], ' "Raging Bull"': ['  97', '1980'], ' "True Confessions"': ['  75', '1981'], ' "The King of Comedy"': ['  90', '1983'], ' "Once Upon a Time in America"': ['  89', '1984'], ' "Falling in Love"': ['  60', '1984'], ' "Brazil"': ['  98', '1985'], ' "The Mission"': ['  65', '1986'], ' "Dear America: Letters Home From Vietnam"': [' 100', '1987'], ' "The Untouchables"': ['  80', '1987'], ' "Angel Heart"': ['  78', '1987'], ' "Midnight Run"': ['  96', '1988'], ' "Jacknife"': ['  64', '1989'], ' "We\'re No Angels"': ['  47', '1989'], ' "Awakenings"': ['  88', '1990'], ' "Stanley & Iris"': ['  29', '1990'], ' "Goodfellas"': ['  96', '1990'], ' "Cape Fear"': ['  76', '1991'], ' "Mistress"': ['  69', '1991'], ' "Guilty by Suspicion"': ['  65', '1991'], ' "Backdraft"': ['  71', '1991'], ' "Thunderheart"': ['  87', '1992'], ' "Night and the City"': ['  67', '1992'], ' "This Boy\'s Life"': ['  75', '1993'], ' "Mad Dog and Glory"': ['  78', '1993'], ' "A Bronx Tale"': ['  96', '1993'], ' "Mary Shelley\'s Frankenstein"': ['  39', '1994'], ' "Casino"': ['  80', '1995'], ' "Heat"': ['  86', '1995'], ' "Sleepers"': ['  74', '1996'], ' "The Fan"': ['  38', '1996'], ' "Marvin\'s Room"': ['  80', '1996'], ' "Wag the Dog"': ['  85', '1997'], ' "Jackie Brown"': ['  87', '1997'], ' "Cop Land"': ['  72', '1997'], ' "Ronin"': ['  68', '1998'], ' "Great Expectations"': ['  38', '1998'], ' "Analyze This"': ['  69', '1999'], ' "Flawless"': ['  43', '1999'], ' "The Adventures of Rocky & Bullwinkle"': ['  43', '2000'], ' "Meet the Parents"': ['  84', '2000'], ' "Men of Honor"': ['  41', '2000'], ' "The Score"': ['  73', '2001'], ' "15 Minutes"': ['  33', '2001'], ' "City by the Sea"': ['  48', '2002'], ' "Analyze That"': ['  27', '2002'], ' "Godsend"': ['   4', '2003'], ' "Shark Tale"': ['  35', '2004'], ' "Meet the Fockers"': ['  38', '2004'], ' "The Bridge of San Luis Rey"': ['   4', '2005'], ' "Rent"': ['  46', '2005'], ' "Hide and Seek"': ['  13', '2005'], ' "The Good Shepherd"': ['  54', '2006'], ' "Arthur and the Invisibles"': ['  21', '2007'], ' "Captain Shakespeare"': ['  76', '2007'], ' "Righteous Kill"': ['  19', '2008'], ' "What Just Happened?"': ['  51', '2008'], ' "Everybody\'s Fine"': ['  46', '2009'], ' "Machete"': ['  72', '2010'], ' "Little Fockers"': ['  10', '2010'], ' "Stone"': ['  50', '2010'], ' "Killer Elite"': ['  25', '2011'], ' "New Year\'s Eve"': ['   7', '2011'], ' "Limitless"': ['  70', '2011'], ' "Silver Linings Playbook"': ['  92', '2012'], ' "Being Flynn"': ['  51', '2012'], ' "Red Lights"': ['  29', '2012'], ' "Last Vegas"': ['  46', '2013'], ' "The Big Wedding"': ['   7', '2013'], ' "Grudge Match"': ['  29', '2013'], ' "Killing Season"': ['  11', '2013'], ' "The Bag Man"': ['   9', '2014'], ' "Joy"': ['  60', '2015'], ' "Heist"': ['  26', '2015'], ' "The Intern"': ['  61', '2015'], ' "Dirty Grandpa"': ['  11', '2016']}

# %% [markdown]
# ¿Cuantas peliculas hay registradas en el archivo .csv?

# %%
#Escribir el codigo para responder la pregunta en esta celda
print(len(diccionario))
# Out:
# 88

# %% [markdown]
# Imprimir las peliculas mejor y peor rankeadas del archivo (imprimir sus respectivos rankings)

# %%
lista=[]
for clave in diccionario:
  rating=diccionario[clave][0].strip()
  try:
    lista.append([int(rating),clave])
  except:
    pass
lista.sort(reverse=True)
print(lista)
# Out:
# [[100, ' "Dear America: Letters Home From Vietnam"'], [99, ' "Taxi Driver"'], [98, ' "Mean Streets"'], [98, ' "Brazil"'], [97, ' "The Godfather'], [97, ' "Raging Bull"'], [96, ' "Midnight Run"'], [96, ' "Goodfellas"'], [96, ' "A Bronx Tale"'], [93, ' "The Deer Hunter"'], [92, ' "Silver Linings Playbook"'], [90, ' "The King of Comedy"'], [89, ' "Once Upon a Time in America"'], [88, ' "Bang the Drum Slowly"'], [88, ' "Awakenings"'], [87, ' "Thunderheart"'], [87, ' "Jackie Brown"'], [86, ' "Heat"'], [86, ' "Greetings"'], [85, ' "Wag the Dog"'], [84, ' "Meet the Parents"'], [80, ' "The Untouchables"'], [80, ' "Marvin\'s Room"'], [80, ' "Casino"'], [78, ' "Mad Dog and Glory"'], [78, ' "Angel Heart"'], [76, ' "Captain Shakespeare"'], [76, ' "Cape Fear"'], [75, ' "True Confessions"'], [75, ' "This Boy\'s Life"'], [74, ' "Sleepers"'], [73, ' "The Score"'], [73, ' "Hi'], [72, ' "Machete"'], [72, ' "Cop Land"'], [71, ' "Backdraft"'], [70, ' "Limitless"'], [69, ' "Mistress"'], [69, ' "Analyze This"'], [68, ' "Ronin"'], [67, ' "Night and the City"'], [67, ' "New York'], [65, ' "The Mission"'], [65, ' "Guilty by Suspicion"'], [64, ' "Jacknife"'], [61, ' "The Intern"'], [60, ' "Joy"'], [60, ' "Falling in Love"'], [54, ' "The Good Shepherd"'], [51, ' "What Just Happened?"'], [51, ' "Being Flynn"'], [50, ' "Stone"'], [48, ' "City by the Sea"'], [47, ' "We\'re No Angels"'], [47, ' "1900"'], [46, ' "Rent"'], [46, ' "Last Vegas"'], [46, ' "Everybody\'s Fine"'], [43, ' "The Adventures of Rocky & Bullwinkle"'], [43, ' "Flawless"'], [41, ' "The Last Tycoon"'], [41, ' "Men of Honor"'], [40, ' "Born to Win"'], [39, ' "Mary Shelley\'s Frankenstein"'], [38, ' "The Fan"'], [38, ' "Meet the Fockers"'], [38, ' "Great Expectations"'], [35, ' "Shark Tale"'], [33, ' "15 Minutes"'], [29, ' "Stanley & Iris"'], [29, ' "Red Lights"'], [29, ' "Grudge Match"'], [27, ' "Analyze That"'], [26, ' "Heist"'], [25, ' "Killer Elite"'], [21, ' "Arthur and the Invisibles"'], [19, ' "Righteous Kill"'], [17, ' "Bloody Mama"'], [13, ' "Hide and Seek"'], [11, ' "Killing Season"'], [11, ' "Dirty Grandpa"'], [10, ' "Little Fockers"'], [9, ' "The Bag Man"'], [7, ' "The Big Wedding"'], [7, ' "New Year\'s Eve"'], [4, ' "The Bridge of San Luis Rey"'], [4, ' "Godsend"']]

# %% [markdown]
# # Base de datos - Relacionales
#
# SQLite es una biblioteca de C que provee una base de datos ligera basada en disco que no requiere un proceso de servidor separado y permite acceder a la base de datos usando una variación no estándar del lenguaje de consulta SQL. Algunas aplicaciones pueden usar SQLite para almacenamiento interno. También es posible prototipar una aplicación usando SQLite y luego transferir el código a una base de datos más grande como PostgreSQL u Oracle.

# %% [markdown]
# Realizamos el `import` e indicamos el archivo en el que vamos a guardar la base de datos:

# %%
import sqlite3
conn = sqlite3.connect('db.db')

# %% [markdown]
# La siguiente linea de codigo agrega filas a la misma. Por favor, ejecutar la siguiente celda para la consigna:

# %%
# !wget https://people.sc.fsu.edu/~jburkardt/data/csv/snakes_count_10000.csv

cur = conn.cursor()
cur.execute("CREATE TABLE t (GameNumber, GameLength);")

with open('snakes_count_10000.csv','r') as csv_file:
  lines = csv_file.readlines()[1:]
  lines = [l.split(',') for l in lines]
  to_db = [(l[0].strip(), l[1].strip()) for l in lines]

cur.executemany("INSERT INTO t (GameNumber, GameLength) VALUES (?, ?);", to_db)
conn.commit()
conn.close()
# Out:
# --2024-11-22 17:00:33--  https://people.sc.fsu.edu/~jburkardt/data/csv/snakes_count_10000.csv
# Resolving people.sc.fsu.edu (people.sc.fsu.edu)... 144.174.0.22
# Connecting to people.sc.fsu.edu (people.sc.fsu.edu)|144.174.0.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89011 (87K) [text/csv]
# Saving to: ‘snakes_count_10000.csv’
#
# snakes_count_10000. 100%[===================>]  86.92K   501KB/s    in 0.2s
#
# 2024-11-22 17:00:33 (501 KB/s) - ‘snakes_count_10000.csv’ saved [89011/89011]

# %% [markdown]
# ## Consignas

# %% [markdown]
# ¿Como luce la base de datos? Imprimirla.

# %%
#Escribir el codigo para responder la pregunta en esta celda
', '51'), ('215', '9'), ('216', '33'), ('217', '47'), ('218', '13'), ('219', '59'), ('220', '17'), ('221', '9'), ('222', '51'), ('223', '26'), ('224', '39'), ('225', '39'), ('226', '35'), ('227', '18'), ('228', '45'), ('229', '36'), ('230', '34'), ('231', '30'), ('232', '34'), ('233', '36'), ('234', '14'), ('235', '7'), ('236', '28'), ('237', '34'), ('238', '49'), ('239', '95'), ('240', '66'), ('241', '36'), ('242', '32'), ('243', '25'), ('244', '25'), ('245', '30'), ('246', '15'), ('247', '12'), ('248', '40'), ('249', '32'), ('250', '26'), ('251', '18'), ('252', '60'), ('253', '21'), ('254', '79'), ('255', '17'), ('256', '42'), ('257', '40'), ('258', '23'), ('259', '39'), ('260', '58'), ('261', '19'), ('262', '45'), ('263', '17'), ('264', '66'), ('265', '31'), ('266', '25'), ('267', '38'), ('268', '16'), ('269', '36'), ('270', '20'), ('271', '29'), ('272', '26'), ('273', '32'), ('274', ' ...

# %% [markdown]
# ¿Cuantas filas hay en la base de datos?

# %%
#Escribir el codigo para responder la pregunta en esta celda
conn = sqlite3.connect('db.db')
cur = conn.cursor()
cur.execute("SELECT * FROM t;")
print(len(cur.fetchall()))
cur.close()
# Out:
# 10000

# %% [markdown]
# ¿Cual es el máximo `GameLength` y en qué `GameNumber` se realizó?

# %%
#Escribir el codigo para responder la pregunta en esta celda
conn = sqlite3.connect('db.db')
cur = conn.cursor()
cur.execute("SELECT GameNumber, CAST(GameLength AS int) as gln FROM t ORDER BY gln DESC ;")
print(cur.fetchall())
cur.close()
# Out:
# [('4462', 203), ('202', 197), ('8669', 194), ('7531', 190), ('7720', 187), ('6608', 180), ('7387', 180), ('7911', 180), ('2614', 178), ('9737', 178), ('8646', 177), ('6981', 167), ('5230', 166), ('8802', 163), ('4700', 162), ('2308', 158), ('6207', 158), ('561', 157), ('7176', 156), ('9817', 156), ('4171', 155), ('6349', 153), ('707', 152), ('8856', 152), ('1829', 151), ('1945', 151), ('2645', 151), ('5058', 151), ('7717', 151), ('8309', 151), ('9623', 151), ('2759', 150), ('2898', 150), ('5158', 150), ('3342', 149), ('7402', 149), ('496', 144), ('2425', 144), ('3669', 144), ('3832', 144), ('4299', 144), ('4387', 143), ('8743', 142), ('5057', 141), ('5434', 141), ('5503', 141), ('7121', 141), ('8940', 141), ('4957', 140), ('1854', 139), ('9770', 139), ('9696', 138), ('5748', 137), ('112', 136), ('330', 136), ('5625', 135), ('9602', 135), ('1414', 134), ('2744', 134), ('7050', 134), ('277', 133), ('1616', 133), ('5160', 133), ('9779', 133), ('1348', 132), ('2399', 132), ('8719', 132), ('1987', 130), ('6376', 130), ('7268', 130), ('321', 129), ('2485', 129), ('4759', 129), ('5000', 129), ('9014', 129), ('1087', 128), ('1946', 128), ('4089', 128), ('6317', 128), ('9087', 128), ('65', 127), ('2006', 127), ('2317', 127), ('4570', 127), ('5264', 127), ('8234', 127), ('8471', 127), ('2173', 126), ('4671', 126), ('5462', 126), ('9909', 126), ('2060', 125), ('3571', 125), ('5458', 125), ('5506', 125), ('5977', 125), ('7699', 125), ('9412', 125), ('1034', 124), ('1881', 123), ('7815', 123), ('8446
# %% [markdown]
# ## Consigna

# %% [markdown]
# Hacer una request GET e imprimir uno de los campos de la respuesta:

# %%
#Escribir el codigo para responder la pregunta en esta celda
import requests
url="https://api.steemit.com"
response=requests.get(url)
if response.status_code==200:
  data=response.json()
  print("Datos recibidos:")
  print(data)
else:
  print("Error en la solicitud:", response.status_code)
# Out:
# Datos recibidos:
# {'status': 'OK', 'datetime': '2024-11-22T17:00:44.795956', 'source_commit': 'ae6c6c77601436e496a8816ece2cbc6e26fbe3c2', 'docker_tag': 'latest', 'jussi_num': 90596547}

# %% [markdown]
# Hacer una request GET y, apartir de los campos en la respuesta, generar otro campo (por ejemplo, si la respuesta solo incluye un timestamp y una posición del registro, elaborar la velocidad del registro)

# %%
#Escribir el codigo para responder la pregunta en esta celda
import requests
url="https://api.steemit.com"
response=requests.get(url)
if response.status_code==200:
  data=response.json()
  print("Datos recibidos:")
  print(data)
# Out:
# Datos recibidos:
# {'status': 'OK', 'datetime': '2024-11-22T16:59:00.551846', 'source_commit': 'ae6c6c77601436e496a8816ece2cbc6e26fbe3c2', 'docker_tag': 'latest', 'jussi_num': 90596508}

# %% [markdown]
# # Streaming data
# Ahora vamos a hacer algo muy parecido a lo anterior, pero vamos a usar APIs que nos ofrecen datos en tiempo real. Pueden encontrar APIs de este estilo [en este repositorio](https://github.com/ColinEberhardt/awesome-public-streaming-datasets) (pueden elegir otras que no son de ese repositorio)

# %% [markdown]
# ## Consigna

# %% [markdown]
# Hacer un plot con `matplotlib` de una variable de una API de datos streaming en el que el eje 'y' sea la variable y el eje 'x' el tiempo.

# %%
#Escribir el codigo para responder la pregunta en esta celda
import requests
import matplotlib.pyplot as plt
from datetime import datetime
import time
def precios_bitcoin():
  url = "https://api.coingecko.com/api/v3/simple/price"

  params = {
      "ids": "bitcoin",
      "vs_currencies": "usd",
  }
  res = requests.get(url, params=params)
  if res.status_code == 200:
    datos = res.json()
    return datos["bitcoin"]["usd"]
  else:
    print("Error en la solicitud:",response.status_code)
    return None
tiempos = [] # Para graficar con facilidad
precios = [] # Para graficar con facilidad


numero_puntos = 10 # Si queres mas puntos, subi el numero este
intervalo = 10 # Esto es el tiempo que va a pasar entre soliticud, yo puse 10, que no se cuantos segundos son. Si queres que sea mas rapido achicalo

for _ in range(numero_puntos):
    precio = precios_bitcoin()
    tiempo_actual = datetime.now().strftime('%H:%M:%S')

    if precio is not None:
        tiempos.append(tiempo_actual)
        precios.append(precio)
        print(f"{tiempo_actual}: ${precio}")
    else:
        print(f"{tiempo_actual}: No se pudo obtener el precio.")

    time.sleep(intervalo)


plt.figure(figsize=(10, 5))
plt.plot(tiempos, precios, marker='o', linestyle='-', color='b')
plt.xlabel('Tiempo')
plt.ylabel('Precio de Bitcoin (USD)')
plt.title('Precio de Bitcoin en Tiempo Real')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 17:01:12: $98988
# 17:01:22: $98988
# 17:01:32: $98988
# 17:01:42: $99083
# 17:01:52: $99083
# 17:02:03: $99083
# 17:02:13: $99083
# Error en la solicitud: 200
# 17:02:23: No se pudo obtener el precio.
# Error en la solicitud: 200
# 17:02:33: No se pudo obtener el precio.
# Error en la solicitud: 200
# 17:02:43: No se pudo obtener el precio.
